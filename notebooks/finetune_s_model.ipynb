# %%
from finetune_s_model import finetune_full_s_model

# %%
finetune_full_s_model(patience=3, thresh_grid=None, max_epochs=20, ds_choice=1, smple_rate=100, smodel='ModelPS/ModelPS/modelS_STEAD_sigma20.pth', best_model='best_modelS_STEAD_sigma20_TXED_sigma10.pth', final_model='final_modelS_STEAD_sigma20_TXED_sigma10.pth')
